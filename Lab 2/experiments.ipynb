# %%
import matplotlib.pyplot as plt
from EM import EM, NiftiManager, Evaluate
import numpy as np
import os 
from sklearn.cluster import KMeans


# To allow auto reload to this notebook after modifying any external file imported
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
NM      = NiftiManager()
EVAL    = Evaluate()

# %%
subject_id = 1

data_folder_path    = os.path.join(os.getcwd(), f'../Lab 1/P2_data/{subject_id}')

labels_nifti, _ = NM.load_nifti(os.path.join(data_folder_path, 'LabelsForTesting.nii'))
segmentation_result_1 = EM(subject_id, params_init_type='kmeans', modality='multi').fit(n_iterations=20)

segmentation_result_1_CSF   = segmentation_result_1 == 1
segmentation_result_1_GM    = segmentation_result_1 == 2
segmentation_result_1_WM    = segmentation_result_1 == 3

labels_nifti_CSF            = labels_nifti == 1
labels_nifti_GM             = labels_nifti == 2
labels_nifti_WM             = labels_nifti == 3

print("CSF DICE: ", EVAL.calc_dice_coefficient(labels_nifti_CSF, segmentation_result_1_CSF))
print("WM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_WM, segmentation_result_1_WM))
print("GM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_GM, segmentation_result_1_GM))

NM.show_label_seg_nifti(labels_nifti_WM, segmentation_result_1_WM, subject_id)
# Out:
# 2023-10-22 17:03:28.107 | INFO     | EM:initialize_parameters:172 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 17:03:28.109 | INFO     | EM:fit:369 - Fitting the algorithm with 20 iterations.
# 2023-10-22 17:03:28.776 | INFO     | EM:fit:391 - Iterations performed: 4. Displaying the segmentation result..
# 2023-10-22 17:03:28.794 | WARNING  | EM:correct_pred_labels:286 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
# CSF DICE:  0.9037845300368287
# WM DICE:  0.8603989456169875
# GM DICE:  0.8014081389460547

# %%
subject_id = 2

data_folder_path    = os.path.join(os.getcwd(), f'../Lab 1/P2_data/{subject_id}')

labels_nifti, _ = NM.load_nifti(os.path.join(data_folder_path, 'LabelsForTesting.nii'))
segmentation_result_1 = EM(subject_id, params_init_type='kmeans').fit(n_iterations=1)

segmentation_result_1_CSF   = segmentation_result_1 == 1
segmentation_result_1_GM    = segmentation_result_1 == 2
segmentation_result_1_WM    = segmentation_result_1 == 3

labels_nifti_CSF            = labels_nifti == 1
labels_nifti_GM             = labels_nifti == 2
labels_nifti_WM             = labels_nifti == 3

print("CSF DICE: ", EVAL.calc_dice_coefficient(labels_nifti_CSF, segmentation_result_1_CSF))
print("WM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_WM, segmentation_result_1_WM))
print("GM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_GM, segmentation_result_1_GM))

NM.show_label_seg_nifti(labels_nifti_CSF, segmentation_result_1_CSF, subject_id)
# Out:
# 2023-10-22 15:52:24.459 | INFO     | EM:initialize_parameters:166 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 15:52:24.462 | INFO     | EM:fit:364 - Fitting the algorithm with 1 iterations.
# 2023-10-22 15:52:25.584 | INFO     | EM:fit:386 - Iterations performed: 2. Displaying the segmentation result..
# 2023-10-22 15:52:25.604 | WARNING  | EM:correct_pred_labels:281 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
# CSF DICE:  0.8715075482294692
# WM DICE:  0.7420151251331654
# GM DICE:  0.7149708069264755

# %%
subject_id = 3

data_folder_path    = os.path.join(os.getcwd(), f'../Lab 1/P2_data/{subject_id}')

labels_nifti, _ = NM.load_nifti(os.path.join(data_folder_path, 'LabelsForTesting.nii'))
segmentation_result_1 = EM(subject_id, params_init_type='kmeans').fit(n_iterations=1)

segmentation_result_1_CSF   = segmentation_result_1 == 1
segmentation_result_1_GM    = segmentation_result_1 == 2
segmentation_result_1_WM    = segmentation_result_1 == 3

labels_nifti_CSF            = labels_nifti == 1
labels_nifti_GM             = labels_nifti == 2
labels_nifti_WM             = labels_nifti == 3

print("CSF DICE: ", EVAL.calc_dice_coefficient(labels_nifti_CSF, segmentation_result_1_CSF))
print("WM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_WM, segmentation_result_1_WM))
print("GM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_GM, segmentation_result_1_GM))

NM.show_label_seg_nifti(labels_nifti_GM, segmentation_result_1_GM, subject_id)
# Out:
# 2023-10-22 15:28:51.157 | INFO     | EM:initialize_parameters:166 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 15:28:51.161 | INFO     | EM:fit:355 - Fitting the algorithm with 1 iterations.
# 2023-10-22 15:28:51.612 | INFO     | EM:fit:374 - Iterations performed: 2. Displaying the segmentation result..
# 2023-10-22 15:28:51.646 | WARNING  | EM:correct_pred_labels:280 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
# CSF DICE:  0.8343424392831116
# WM DICE:  0.838019149238934
# GM DICE:  0.7284349076628628

# %%
subject_id = 4

data_folder_path    = os.path.join(os.getcwd(), f'../Lab 1/P2_data/{subject_id}')

labels_nifti, _ = NM.load_nifti(os.path.join(data_folder_path, 'LabelsForTesting.nii'))
segmentation_result_1 = EM(subject_id, params_init_type='kmeans').fit(n_iterations=1)

segmentation_result_1_CSF   = segmentation_result_1 == 1
segmentation_result_1_GM    = segmentation_result_1 == 2
segmentation_result_1_WM    = segmentation_result_1 == 3

labels_nifti_CSF            = labels_nifti == 1
labels_nifti_GM             = labels_nifti == 2
labels_nifti_WM             = labels_nifti == 3

print("CSF DICE: ", EVAL.calc_dice_coefficient(labels_nifti_CSF, segmentation_result_1_CSF))
print("WM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_WM, segmentation_result_1_WM))
print("GM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_GM, segmentation_result_1_GM))

NM.show_label_seg_nifti(labels_nifti_WM, segmentation_result_1_WM, subject_id)
# Out:
# 2023-10-22 15:28:52.732 | INFO     | EM:initialize_parameters:166 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 15:28:52.734 | INFO     | EM:fit:355 - Fitting the algorithm with 1 iterations.
# 2023-10-22 15:28:52.990 | INFO     | EM:fit:374 - Iterations performed: 2. Displaying the segmentation result..
# 2023-10-22 15:28:53.011 | WARNING  | EM:correct_pred_labels:280 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
# CSF DICE:  0.8586457557810769
# WM DICE:  0.8026697186726605
# GM DICE:  0.7377573068798537

# %%
subject_id = 5

data_folder_path    = os.path.join(os.getcwd(), f'../Lab 1/P2_data/{subject_id}')

labels_nifti, _ = NM.load_nifti(os.path.join(data_folder_path, 'LabelsForTesting.nii'))
segmentation_result_1 = EM(subject_id, params_init_type='kmeans').fit(n_iterations=20)

segmentation_result_1_CSF   = segmentation_result_1 == 1
segmentation_result_1_GM    = segmentation_result_1 == 2
segmentation_result_1_WM    = segmentation_result_1 == 3

labels_nifti_CSF            = labels_nifti == 1
labels_nifti_GM             = labels_nifti == 2
labels_nifti_WM             = labels_nifti == 3

print("CSF DICE: ", EVAL.calc_dice_coefficient(labels_nifti_CSF, segmentation_result_1_CSF))
print("WM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_WM, segmentation_result_1_WM))
print("GM DICE: ", EVAL.calc_dice_coefficient(labels_nifti_GM, segmentation_result_1_GM))

NM.show_label_seg_nifti(labels_nifti_WM, segmentation_result_1_WM, subject_id)
# Out:
# 2023-10-22 16:51:15.799 | INFO     | EM:initialize_parameters:166 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 16:51:15.801 | INFO     | EM:fit:364 - Fitting the algorithm with 20 iterations.
# 2023-10-22 16:51:19.864 | INFO     | EM:fit:386 - Iterations performed: 7. Displaying the segmentation result..
# 2023-10-22 16:51:19.883 | WARNING  | EM:correct_pred_labels:281 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
# CSF DICE:  0.8686029940879859
# WM DICE:  0.8955829288629474
# GM DICE:  0.8369223204220252

# %% [markdown]
# #### Plotting all segmentation results

# %%
fig, axes = plt.subplots(1, 5, figsize=(15, 3), sharey=True)

# Create a common x-axis label for the entire row of subplots
fig.text(0.11, 0.5, 'Gound Truth', va='center', rotation='vertical', fontsize=12)

for i in range(0,5):
    data_folder_path    = os.path.join(os.getcwd(), f'../Lab 1/P2_data/{i+1}')
    labels_nifti, _     = NM.load_nifti(os.path.join(data_folder_path, 'LabelsForTesting.nii'))

    axes[i].imshow(labels_nifti[:,:,25])
    axes[i].set_title(f'Subject id {i+1}')
    axes[i].axis('off')  # Turn off axis labels
    
#################################################################

fig, axes = plt.subplots(1, 5, figsize=(15, 10), sharey=True)

# Create a common x-axis label for the entire row of subplots
fig.text(0.11, 0.5, 'Segmentation', va='center', rotation='vertical', fontsize=12)

segmentation_results = []

for i in range(0,5):
    subject_id = i+1
    segmentation_result = EM(subject_id, params_init_type='kmeans', modality='multi').fit(n_iterations=10)
    segmentation_results.append(segmentation_result)

for i in range(0,5):    
    axes[i].imshow(segmentation_results[i][:,:,25])
    axes[i].axis('off')  # Turn off axis labels

##################################################################



plt.show()
# Out:
# 2023-10-22 17:34:26.533 | INFO     | EM:initialize_parameters:175 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 17:34:26.536 | INFO     | EM:fit:375 - Fitting the algorithm with 10 iterations.
# 2023-10-22 17:34:27.220 | INFO     | EM:fit:397 - Iterations performed: 4. Displaying the segmentation result..
# 2023-10-22 17:34:27.239 | WARNING  | EM:correct_pred_labels:300 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
# 2023-10-22 17:34:27.598 | INFO     | EM:initialize_parameters:175 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 17:34:27.600 | INFO     | EM:fit:375 - Fitting the algorithm with 10 iterations.
# 2023-10-22 17:34:28.406 | INFO     | EM:fit:397 - Iterations performed: 4. Displaying the segmentation result..
# 2023-10-22 17:34:28.425 | WARNING  | EM:correct_pred_labels:300 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
# 2023-10-22 17:34:28.676 | INFO     | EM:initialize_parameters:175 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 17:34:28.679 | INFO     | EM:fit:375 - Fitting the algorithm with 10 iterations.
# 2023-10-22 17:34:29.764 | INFO     | EM:fit:397 - Iterations performed: 6. Displaying the segmentation result..
# 2023-10-22 17:34:29.798 | WARNING  | EM:correct_pred_labels:300 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
# 2023-10-22 17:34:30.195 | INFO     | EM:initialize_parameters:175 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 17:34:30.197 | INFO     | EM:fit:375 - Fitting the algorithm with 10 iterations.
# 2023-10-22 17:34:30.883 | INFO     | EM:fit:397 - Iterations performed: 4. Displaying the segmentation result..
# 2023-10-22 17:34:30.901 | WARNING  | EM:correct_pred_labels:300 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
# 2023-10-22 17:34:31.212 | INFO     | EM:initialize_parameters:175 - Successfully initialized model parameters using 'kmeans'.
# 2023-10-22 17:34:31.214 | INFO     | EM:fit:375 - Fitting the algorithm with 10 iterations.
# 2023-10-22 17:34:32.347 | INFO     | EM:fit:397 - Iterations performed: 6. Displaying the segmentation result..
# 2023-10-22 17:34:32.369 | WARNING  | EM:correct_pred_labels:300 -
#  `correct_pred_labels` function modifies the labels based on prior knowledge for only the 5 subjects, and not standardised to all brain tissue segmentation
#  mask labels. It is not mandatory to correct the prediction labels, as it is implemented for this specific task and it is performed on the segmented result of the algorithm.
# To hide this warning and not correct the labels, set `correct_labels` to False while fitting.
